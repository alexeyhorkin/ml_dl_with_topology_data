# %%
import os
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

from os.path import join as p_join

import seaborn as sns


##################################
## GLOBAL SETTINGS ###############
##################################
plt.rcParams["figure.figsize"] = (12,8)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}

matplotlib.rc('font', **font)

# %%
import sys
sys.path.append("../../") # Adds higher directory to python modules path.
from utils import utils

# %%
data_0 = {}
N_POINTS = 15000
n_feat=16
data_path = p_join('..', '..', 'data_2')
for prefix in ['L=1.6', 'L=6.6', 'L=7.6', 'L=8.6', 'L=10.6', 'N2=21', 'N2=23', 'N2=25', 'N2=27']:
    FOLDERS = [p_join(os.path.abspath(data_path), item) for item in os.listdir(data_path) if prefix in item]
    X, Y = utils.create_dataset(FOLDERS,feature_nums=n_feat)
    X = utils.normalize_data(X)
    X = X[:N_POINTS]
    Y = Y[:N_POINTS]
    tsne = TSNE(n_components=2, verbose=1, random_state=42)
    tsne_components = tsne.fit_transform(X)
    tsne_df = pd.DataFrame(data=tsne_components, columns = ['tsne1', 'tsne2'])
    tsne_df['target'] = Y
    
    data_0[f'{prefix}'] = tsne_df
# Out:
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 22.43it/s]
# /home/akhorkin/Repositories/ml_dl_with_topology_data/.venv/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/akhorkin/Repositories/ml_dl_with_topology_data/.venv/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 15000 samples in 0.000s...
# [t-SNE] Computed neighbors for 15000 samples in 5.345s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 15000
# [t-SNE] Computed conditional probabilities for sample 2000 / 15000
# [t-SNE] Computed conditional probabilities for sample 3000 / 15000
# [t-SNE] Computed conditional probabilities for sample 4000 / 15000
# ...

# %%
fig = plt.figure(figsize=(12, 8))
for i, k in enumerate(data_0):
    if 'L' in k:
        ax = fig.add_subplot(2, 3, i+1)
        tsne_df = data_0[k]
        ax.scatter(tsne_df['tsne1'], y=tsne_df['tsne2'],
                        c=tsne_df['target'], s=12, alpha=0.3)
        ax.set_title(k)
plt.tight_layout()
h, l = scatter.legend_elements()
ax = fig.add_subplot(2, 3, 6)
ax.set_title('Classes')
ax.legend(h, l, loc=3)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

# %%
fig = plt.figure(figsize=(10, 10))
i = 0
for k in data_0:
    if 'N2' in k:
        i += 1
        ax = fig.add_subplot(2, 2, i)
        tsne_df = data_0[k]
        ax.scatter(tsne_df['tsne1'], y=tsne_df['tsne2'],
                        c=tsne_df['target'], s=12, alpha=0.3)
        ax.set_title(k)
plt.tight_layout()
h, l = scatter.legend_elements()
ax = fig.add_subplot(3, 3, 5)
# ax.set_title('Classes')
ax.legend(h, l, loc=3)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

# %%
data = {}
N_POINTS = 15000
l='L=8.6'
data_path = p_join('..', '..', 'data_2')
for n_feat in [16, 17, 18, 19, 20]:
    FOLDERS = [p_join(os.path.abspath(data_path), item) for item in os.listdir(data_path) if l in item]
    X, Y = utils.create_dataset(FOLDERS,feature_nums=n_feat)
    X = utils.normalize_data(X)
    print(X.shape)
    X = X[:N_POINTS]
    Y = Y[:N_POINTS]
    tsne = TSNE(n_components=2, verbose=1, random_state=42)
    tsne_components = tsne.fit_transform(X)
    tsne_df = pd.DataFrame(data=tsne_components, columns = ['tsne1', 'tsne2'])
    tsne_df['target'] = Y
    
    data[f'{l} n_featuers={n_feat}'] = tsne_df
# Out:
# 100%|███████████████████████████████████████████| 16/16 [00:00<00:00, 22.78it/s]
# /home/akhorkin/Repositories/ml_dl_with_topology_data/.venv/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /home/akhorkin/Repositories/ml_dl_with_topology_data/.venv/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# (63984, 16)
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 15000 samples in 0.000s...
# [t-SNE] Computed neighbors for 15000 samples in 5.216s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 15000
# [t-SNE] Computed conditional probabilities for sample 2000 / 15000
# [t-SNE] Computed conditional probabilities for sample 3000 / 15000
# [t-SNE] Computed conditional probabilities for sample 4000 / 15000
# ...

# %%
# for k in data:
#     tsne_df = data[k]
#     sns.lmplot(x="tsne1", y="tsne2",
#                data=tsne_df, 
#                fit_reg=False, 
#                hue='target', # color by target
#                legend=True,
#                scatter_kws={"s": 7}) # specify the point size
#     ax = plt.gca()
#     ax.set_title(k)
#     pass

# %%
data_1 = {k.split()[1] : v for k, v in data.items()}

# %%
fig = plt.figure(figsize=(12, 8))
for i, k in enumerate(data_1):
    ax = fig.add_subplot(2, 3, i+1)
    tsne_df = data_1[k]
    ax.scatter(tsne_df['tsne1'], y=tsne_df['tsne2'],
                    c=tsne_df['target'], s=12, alpha=0.3)
    ax.set_title(k)
plt.tight_layout()
h, l = scatter.legend_elements()
ax = fig.add_subplot(2, 3, 6)
ax.set_title('Classes')
ax.legend(h, l, loc=3)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
